# %%
import pandas as pd, os
from charts import *
from tests import *

# %% [markdown]
# # Result analysis

# %%
# import
data = pd.read_csv(os.path.join('..', 'data', 'results.csv'))

# %% [markdown]
# ## Statistics

# %%
# task 1 success
my_pie(data, 'task1', 'First protype task success.')

# %%
# task 2 success
my_pie(data, 'task2', 'Second protype task success.')

# %%
# study time statistics
data[['time']].agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#              time
# min      3.801333
# max     44.504817
# mean    18.471819
# median  15.452558
# std     11.576937

# %%
# study time grouped by variant
data.groupby('variant').time.agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#               min        max       mean     median        std
# variant
# ai       7.442950  44.504817  26.079014  22.553192  11.208888
# no-ai    3.801333  23.646267  10.864623   9.621025   5.225276

# %% [markdown]
# ## Reasonable questions

# %%
# questions reasonable
data.groupby('variant')[['reasonableQuestions']].agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#         reasonableQuestions
#                         min max      mean median       std
# variant
# ai                        2   7  5.033333    5.0  1.376736
# no-ai                     5   7  6.566667    7.0  0.568321

# %%
data[['reasonableQuestions', 'variant']].plot.hist(by='variant', range=[1, 7], bins=7)
# Out:
# array([<Axes: title={'center': 'ai'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'no-ai'}, ylabel='Frequency'>],
#       dtype=object)

# %%
# t-test for reasonable question differences
my_ttest(data, ['reasonableQuestions'], 'variant', ['no-ai', 'ai'])
# Out:
#               Property     t       p    df     d  significant
# 0  reasonableQuestions  5.64  < .001  58.0  0.49         True

# %%
# u-test for reasonable question differences
my_mannwhitney(data, ['reasonableQuestions'], 'variant', ['no-ai', 'ai'])
# Out:
#               Property      U     z       p     r  significant
# 0  reasonableQuestions  756.5  4.54  < .001  0.59         True
